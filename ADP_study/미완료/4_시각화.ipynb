# %% [markdown]
# # [ PART 04. 시각화 ]

# %% [markdown]
# ## - 불러올 패키지 목록

# %%
# 데이터 핸들링을 위한 패키지
import numpy as np
import pandas as pd

# 시각화를 위한 패키지
import seaborn as sb
import matplotlib.pyplot as plt

# %matplotlib inline 의 목적은 plt.show()함수가 호출되지 않은 경우에도 matplotlib 다이어그램을 렌더링하는 것이다.
# 그러나 현재 업데이트된 버전의 주피터 노트북 버전에서는 %matplotlib inline 를 사용하지 않더라도 Matplotlib 다이어그램을 개체로 표현한다.
# 따라서 굳이 필요하지는 않다. 그러나 코드를 깨끗하게 유지하고 자신이 만든 플롯을 호출하기 위해 여전히 관례적으로 권장된다.
# %matplotlib inline

# 그래프 스타일 서식 지정
plt.style.use('default')

# 한글 폰트 설정
plt.rc('font', family='Malgun Gothic')

# 그래프 축의 음수 표현 오류 방지
plt.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# ## 1. 산점도

# %% [raw]
# [Problem]
# - Cars93 데이터는 1993년 승용차 모델 중 무작위로 선택된 93개의 차량에 대한 모델명, 차종, 가격, 엔진 크기 등의 정보를 담고 있는 데이터이다.
# - Cars93의 Length와 Weight변수에 대한 산점도를 출력하라.

# %% [markdown]
# .
# maker 스타일 참고:
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html?highlight=plot#matplotlib.pyplot.plot
# .

# %%
df_cars93 = pd.read_csv( 'C:\\Users\\Administrator\\GitHub\\TIL\\ADP_study\\rawdata\\cars93.csv',
                         index_col = 'Unnamed: 0' )

df_cars93
# Out:
#    Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 1         Acura  Integra    Small       12.9   15.9       18.8        25
# 2         Acura   Legend  Midsize       29.2   33.9       38.7        18
# 3          Audi       90  Compact       25.9   29.1       32.3        20
# 4          Audi      100  Midsize       30.8   37.7       44.6        19
# 5           BMW     535i  Midsize       23.7   30.0       36.2        22
# ..          ...      ...      ...        ...    ...        ...       ...
# 89   Volkswagen  Eurovan      Van       16.6   19.7       22.7        17
# 90   Volkswagen   Passat  Compact       17.6   20.0       22.4        21
# 91   Volkswagen  Corrado   Sporty       22.9   23.3       23.7        18
# 92        Volvo      240  Compact       21.8   22.7       23.5        21
# 93        Volvo      850  Midsize       24.8   26.7       28.5        20
#
#     MPG.highway             AirBags DriveTrain  ... Passengers  Length  \
# ...

# %% [markdown]
# .
# maker 스타일 참고:
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html?highlight=plot#matplotlib.pyplot.plot
# .

# %%
df_cars93.plot( x = 'Length', y = 'Weight',
                kind = 'scatter',  # 그래프 종류
                figsize = (10,7),  # 그래프 사이즈
                marker = 'v',  # marker 종류
                s = 70,  # marker 크기
                c = 'm' )  # 색상

# 그래프 제목
plt.title( 'Scatter Plot - length vs. weight', size = 20 )

# 축 이름
plt.xlabel( 'Length', size=20 )
plt.ylabel( 'Weight', size=20 )

# 좌표축 범위
plt.xlim(130, 230)
plt.ylim(1500, 4400)

plt.show()

# %% [markdown]
# ### 미해결 : 옵션을 plot() 으로만 구현할 경우 title과 label의 사이즈 조절은?????

# %%
# 옵션을 plot() 으로만 구현할 경우 제목의 사이트 조절은?????

df_cars93.plot( x = 'Length', y = 'Weight',
                kind = 'scatter',
                figsize = (10,7),
                title = 'Scatter Plot - length vs. weight',
                xlabel = 'Length',
                ylabel = 'Weight',
                xlim = (130, 230),
                ylim = (1500, 4400) )

plt.show()

# %% [raw]
# [Problem]
# - airquality는 1973년 5월부터 9월까지 뉴욕의 대기 오염에 대한 기록이다.
# - airquality에서 월(Month 변수)별 평균 온도(Temp 변수의 평균값)를 한 눈에 알아볼 수 있도록 plot함수를 사용해 꺾은선 그래프로 시각화하라.

# %%
df_airq = pd.read_csv( 'C:\\Users\\Administrator\\GitHub\\TIL\\ADP_study\\rawdata\\airquality.csv',
                         index_col = 'Unnamed: 0' )

df_airq
# Out:
#      Ozone  Solar.R  Wind  Temp  Month  Day
# 1     41.0    190.0   7.4    67      5    1
# 2     36.0    118.0   8.0    72      5    2
# 3     12.0    149.0  12.6    74      5    3
# 4     18.0    313.0  11.5    62      5    4
# 5      NaN      NaN  14.3    56      5    5
# ..     ...      ...   ...   ...    ...  ...
# 149   30.0    193.0   6.9    70      9   26
# 150    NaN    145.0  13.2    77      9   27
# 151   14.0    191.0  14.3    75      9   28
# 152   18.0    131.0   8.0    76      9   29
# 153   20.0    223.0  11.5    68      9   30
#
# [153 rows x 6 columns]

# %%
group_air = df_airq.groupby('Month')['Temp'].mean()
group_air
# Out:
# Month
# 5    65.548387
# 6    79.100000
# 7    83.903226
# 8    83.967742
# 9    76.900000
# Name: Temp, dtype: float64

# %%
group_air.plot( kind = 'line',
                marker = 'o', markersize = 7 )

plt.title( '월별 평균온도', size = 20 )
plt.xlabel( '월', size=15 )
plt.ylabel( '평균온도', size=15 )

plt.show()

# %% [raw]
# [Problem]
# - Cars93 데이터에서 자동차의 길이(Length)별 평균 무게(Weight)에 대한 산점도를 출력하라.

# %%
group_car = df_cars93.groupby('Length')['Weight'].mean()

df_group_car = pd.DataFrame( { 'Length' : group_car.index,
                               'Weight' : group_car.values } )

df_group_car.head()
# Out:
#    Length  Weight
# 0     141  1845.0
# 1     146  2045.0
# 2     151  1695.0
# 3     159  2810.0
# 4     161  1965.0

# %%
df_group_car.plot( kind='scatter',
                   x = 'Length',
                   y = 'Weight' )
# Out:
# <AxesSubplot:xlabel='Length', ylabel='Weight'>

# %%
df_group_car.plot( kind = 'line',
                   x = 'Length',
                   y = 'Weight',
                   ls = '-.',  # 선 종류
                   lw = 3 )  # 선 굵기

plt.title( '길이별 평균무게', size = 20 )
plt.xlabel( '길이', size=15 )
plt.ylabel( '평균무게', size=15 )

plt.show()

# %% [markdown]
# .
# line 스타일 참고:
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html?highlight=plot#matplotlib.pyplot.plot
# .

# %% [markdown]
# ### 1.2. 그래프 서식

# %% [markdown]
# #### 1.2.1. 여러 개의 그래프를 한 화면에 나타내기(par)

# %%
fig = plt.figure( figsize = (25, 7) )
ax1 = fig.add_subplot(1, 2, 1)
ax2 = fig.add_subplot(1, 2, 2)

group_car.plot( kind = 'line',
           marker = 'o',  # marker 종류
           markersize = 9,  # marker 크기
           c = 'm',  # 색상
           ls = '-.',  # 선 종류
           ax = ax1 )  # matplotlib axes 객체

ax1.set_title( '길이별 평균무게', size = 20 )
ax1.set_xlabel( '길이', size=20 )
ax1.set_ylabel( '평균무게', size=20 )


group_air.plot( kind = 'line',
                marker = 'o', markersize = 7,
                ax = ax2 )

ax2.set_title( '월별 평균온도', size = 20 )
ax2.set_xlabel( '평균온도', size=20 )
ax2.set_ylabel( '월', size=20 )



plt.show()

# %% [markdown]
# #### 1.2.2. 범례(legend)

# %% [markdown]
# ##### 범례 위치 지정(1) - 위치 이름으로 지정

# %%
fig = plt.figure( figsize = (30, 15) )
ax0 = fig.add_subplot(3, 4, 1)
ax1 = fig.add_subplot(3, 4, 2)
ax2 = fig.add_subplot(3, 4, 3)
ax3 = fig.add_subplot(3, 4, 4)
ax4 = fig.add_subplot(3, 4, 5)
ax5 = fig.add_subplot(3, 4, 6)
ax6 = fig.add_subplot(3, 4, 7)
ax7 = fig.add_subplot(3, 4, 8)
ax8 = fig.add_subplot(3, 4, 9)
ax9 = fig.add_subplot(3, 4, 10)
ax10 = fig.add_subplot(3, 4, 11)


group_air.plot( kind = 'line', ax = ax0 )
group_air.plot( kind = 'line', ax = ax1 )
group_air.plot( kind = 'line', ax = ax2 )
group_air.plot( kind = 'line', ax = ax3 )
group_air.plot( kind = 'line', ax = ax4 )
group_air.plot( kind = 'line', ax = ax5 )
group_air.plot( kind = 'line', ax = ax6 )
group_air.plot( kind = 'line', ax = ax7 )
group_air.plot( kind = 'line', ax = ax8 )
group_air.plot( kind = 'line', ax = ax9 )
group_air.plot( kind = 'line', ax = ax10 )


ax0.legend( labels = ['best 위치'],
            loc = 'best', fontsize = 15)

ax1.legend( labels = ['upper right 위치'],
            loc = 'upper right', fontsize = 15)

ax2.legend( labels = ['upper left 위치'],
            loc = 'upper left', fontsize = 15)

ax3.legend( labels = ['lower left'],
            loc = 'lower left', fontsize = 15)

ax4.legend( labels = ['lower right'],
            loc = 'lower right', fontsize = 15)

ax5.legend( labels = ['right'],
            loc = 'right', fontsize = 15)

ax6.legend( labels = ['center left'],
            loc = 'center left', fontsize = 15)

ax7.legend( labels = ['center right'], 
            loc = 'center right', fontsize = 15)

ax8.legend( labels = ['lower center'], 
            loc = 'lower center', fontsize = 15)

ax9.legend( labels = ['upper center'],
            loc = 'upper center', fontsize = 15)

ax10.legend( labels = ['center'],
             loc = 'center', fontsize = 15)


plt.show()

# %% [markdown]
# ##### 범례 위치 지정(2) - 범례 위치에 할당된 숫자로 지정

# %%
fig = plt.figure( figsize = (30, 15) )
ax0 = fig.add_subplot(3, 4, 1)
ax1 = fig.add_subplot(3, 4, 2)
ax2 = fig.add_subplot(3, 4, 3)
ax3 = fig.add_subplot(3, 4, 4)
ax4 = fig.add_subplot(3, 4, 5)
ax5 = fig.add_subplot(3, 4, 6)
ax6 = fig.add_subplot(3, 4, 7)
ax7 = fig.add_subplot(3, 4, 8)
ax8 = fig.add_subplot(3, 4, 9)
ax9 = fig.add_subplot(3, 4, 10)
ax10 = fig.add_subplot(3, 4, 11)


group_air.plot( kind = 'line', ax = ax0 )
group_air.plot( kind = 'line', ax = ax1 )
group_air.plot( kind = 'line', ax = ax2 )
group_air.plot( kind = 'line', ax = ax3 )
group_air.plot( kind = 'line', ax = ax4 )
group_air.plot( kind = 'line', ax = ax5 )
group_air.plot( kind = 'line', ax = ax6 )
group_air.plot( kind = 'line', ax = ax7 )
group_air.plot( kind = 'line', ax = ax8 )
group_air.plot( kind = 'line', ax = ax9 )
group_air.plot( kind = 'line', ax = ax10 )


ax0.legend( labels = ['best 위치'],
            loc = 0, fontsize = 15)

ax1.legend( labels = ['upper right 위치'],
            loc = 1, fontsize = 15)

ax2.legend( labels = ['upper left 위치'],
            loc = 2, fontsize = 15)

ax3.legend( labels = ['lower left'],
            loc = 3, fontsize = 15)

ax4.legend( labels = ['lower right'],
            loc = 4, fontsize = 15)

ax5.legend( labels = ['right'],
            loc = 5, fontsize = 15)

ax6.legend( labels = ['center left'],
            loc = 6, fontsize = 15)

ax7.legend( labels = ['center right'],
            loc = 7, fontsize = 15)

ax8.legend( labels = ['lower center'],
            loc = 8, fontsize = 15)

ax9.legend( labels = ['upper center'],
            loc = 9, fontsize = 15)

ax10.legend( labels = ['center'],
             loc = 10, fontsize = 15)


plt.show()

# %% [markdown]
# ##### 범례 위치 지정(3) - 좌표로 지정

# %%
fig = plt.figure( figsize = (30, 10) )
ax0 = fig.add_subplot(1, 3, 1)
ax1 = fig.add_subplot(1, 3, 2)
ax2 = fig.add_subplot(1, 3, 3)

group_air.plot( kind = 'line', ax = ax0 )
group_air.plot( kind = 'line', ax = ax1 )
group_air.plot( kind = 'line', ax = ax2 )


ax0.legend( labels = ['(0.1, 0.1)위치'],
            bbox_to_anchor=(0.1, 0.1), fontsize = 15)

ax1.legend( labels = ['(0.4, 0.4)위치'],
            bbox_to_anchor=(0.4, 0.4), fontsize = 15)

ax2.legend( labels = ['(0.8, 0.8)위치'],
            bbox_to_anchor=(0.8, 0.8), fontsize = 15)


plt.show()

# %% [markdown]
# ## 2. 그래프

# %% [markdown]
# ### 2.2. 선 그래프

# %% [markdown]
# #### 2.2.1. 꺾은선 그래프

# %%
df_cars = pd.read_csv( 'C:\\Users\\Administrator\\GitHub\\TIL\\ADP_study\\rawdata\\cars.csv',
                         index_col = 'Unnamed: 0' )

df_cars.head()
# Out:
#    speed  dist
# 1      4     2
# 2      4    10
# 3      7     4
# 4      7    22
# 5      8    16

# %%
df_cars.plot( kind = 'line',
                   x = 'speed',
                   y = 'dist',
                   ls = '-.',  # 선 종류
                   lw = 3 )  # 선 굵기
# Out:
# <AxesSubplot:xlabel='speed'>

# %% [markdown]
# ##### 지역 가중 다항식 회귀선: `lowess` 옵션

# %%
sb.regplot( data = df_cars,
            x = 'speed', y = 'dist',
            lowess = True )
# Out:
# <AxesSubplot:xlabel='speed', ylabel='dist'>

# %% [markdown]
# #### 2.2.2. 직선 그래프

# %%
sb.regplot( data = df_cars,
            x = 'speed', y = 'dist',
            order = 1 )
# Out:
# <AxesSubplot:xlabel='speed', ylabel='dist'>

# %% [markdown]
# #### 2.2.3. 곡선 그래프

# %%
x = [ a for a in range(-6,6) ]
y = [ b*b for b in range(-6,6) ]

plt.plot(x,y)

# %% [markdown]
# ### 2.3. 막대 그래프

# %% [raw]
# Cars93 데이터의 Origin변수는 해당 차량이 미국에서 제조되었는지(USA) 혹은 다른 국가에서 제조되었는지(non-USA)를 나타내는 변수이다.
# - Cylinders변수는 실린더의 수를 나타내며, 3,4,5,6,8,rotary의 6개 범주로 이루어져 있다.
# - 두 범주형 변수의 각 레벨에 속하는 데이터의 개수를 막대그래프로 나타내보자.

# %% [markdown]
# #### 2.3.1. 단일 범주형 변수를 막대그래프로 표현

# %% [raw]
# Q) Origin변수와 Cylinders변수의 범주에 속하는 데이터의 개수를 각각 막대그래프로 표현하라.

# %%
# 그룹별 행의 개수 세기
group_origin = df_cars93.groupby('Origin').size()
group_cyl = df_cars93.groupby('Cylinders').size()

# %%
group_origin.plot( kind = 'bar' )
# Out:
# <AxesSubplot:xlabel='Origin'>

# %%
group_cyl.plot( kind = 'bar' )
# Out:
# <AxesSubplot:xlabel='Cylinders'>

# %% [markdown]
# #### 2.3.2. 여러 개의 범주형 변수를 막대그래프로 표현

# %% [raw]
# Q) Origin변수와 Cylinders변수의 범주별 데이터 개수를 막대그래프로 한 번에 표현하라.

# %%
group_org_cly = df_cars93.groupby(['Cylinders', 'Origin']).size()
group_org_cly
# Out:
# Cylinders  Origin
# 3          non-USA     3
# 4          USA        22
#            non-USA    27
# 5          non-USA     2
# 6          USA        20
#            non-USA    11
# 8          USA         6
#            non-USA     1
# rotary     non-USA     1
# dtype: int64

# %%
a = group_org_cly.unstack()
a
# Out:
# Origin      USA  non-USA
# Cylinders
# 3           NaN      3.0
# 4          22.0     27.0
# 5           NaN      2.0
# 6          20.0     11.0
# 8           6.0      1.0
# rotary      NaN      1.0

# %%
a.plot( kind = 'bar' )
# Out:
# <AxesSubplot:xlabel='Cylinders'>

# %%
a.plot( kind = 'bar', stacked = True )
# Out:
# <AxesSubplot:xlabel='Cylinders'>

# %% [markdown]
# ### 2.4. 히스토그램

# %% [raw]
# [Problem]
# - iris데이터의 Petal.Lengh변수에 대해 막대 구간의 개수(breaks인자)를 지정하지 않은 히스토그램과 구간의 개수를 5로 지정한 히스토그램을 생성하라.

# %%
df_iris = pd.read_csv( 'C:\\Users\\Administrator\\GitHub\\TIL\\ADP_study\\rawdata\\iris.csv',
                         index_col = 'Unnamed: 0' )

df_iris
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 1             5.1          3.5           1.4          0.2     setosa
# 2             4.9          3.0           1.4          0.2     setosa
# 3             4.7          3.2           1.3          0.2     setosa
# 4             4.6          3.1           1.5          0.2     setosa
# 5             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 146           6.7          3.0           5.2          2.3  virginica
# 147           6.3          2.5           5.0          1.9  virginica
# 148           6.5          3.0           5.2          2.0  virginica
# 149           6.2          3.4           5.4          2.3  virginica
# 150           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df_iris['Petal.Length'].plot( kind = 'hist' )
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df_iris['Petal.Length'].plot( kind = 'hist', bins = 5 )
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# ### 2.5. 파이 차트

# %% [raw]
# [Problem]
# - Cars93 데이터의 차량 실린더의 수를 나타내는 Cylinders변수의 범주별 데이터의 수를 파이차트로 표현하라.

# %%
df_cars93 = pd.read_csv( 'C:\\Users\\Administrator\\GitHub\\TIL\\ADP_study\\rawdata\\cars93.csv',
                         index_col = 'Unnamed: 0' )

df_cars93
# Out:
#    Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 1         Acura  Integra    Small       12.9   15.9       18.8        25
# 2         Acura   Legend  Midsize       29.2   33.9       38.7        18
# 3          Audi       90  Compact       25.9   29.1       32.3        20
# 4          Audi      100  Midsize       30.8   37.7       44.6        19
# 5           BMW     535i  Midsize       23.7   30.0       36.2        22
# ..          ...      ...      ...        ...    ...        ...       ...
# 89   Volkswagen  Eurovan      Van       16.6   19.7       22.7        17
# 90   Volkswagen   Passat  Compact       17.6   20.0       22.4        21
# 91   Volkswagen  Corrado   Sporty       22.9   23.3       23.7        18
# 92        Volvo      240  Compact       21.8   22.7       23.5        21
# 93        Volvo      850  Midsize       24.8   26.7       28.5        20
#
#     MPG.highway             AirBags DriveTrain  ... Passengers  Length  \
# ...

# %%
# 그룹별 행의 개수 세기
group_cyl = df_cars93.groupby( 'Cylinders' ).size()
group_cyl
# Out:
# Cylinders
# 3          3
# 4         49
# 5          2
# 6         31
# 8          7
# rotary     1
# dtype: int64

# %%
group_cyl.plot( kind = 'pie', figsize = (15,10),
                autopct='%1.1f%%' )   # 퍼센트 % 표시

plt.title('실린더 개수별 비중', size=20)
plt.xticks( size = 20 )

# 파이 차트의 비율을 같게 (원에 가깝게) 조정
plt.axis('equal')    

plt.legend(labels=group_cyl.index, loc='upper right', fontsize = 12)   # 범례 표시
plt.show()

# %% [markdown]
# ### 2.6. 산점도 행렬

# %% [raw]
# [Problem]
# - 내장 데이터 iris의 Sepal.Length, Sepal.Width, Petal.Length, Petal.Width 변수들에 대한 산점도 행렬을 출력하라.
# - 이 때 species의 각 범주별로 점의 모양과 색을 다르게 지정하라.

# %%
df_iris = pd.read_csv( 'C:\\Users\\Administrator\\GitHub\\TIL\\ADP_study\\rawdata\\iris.csv',
                         index_col = 'Unnamed: 0' )

df_iris
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 1             5.1          3.5           1.4          0.2     setosa
# 2             4.9          3.0           1.4          0.2     setosa
# 3             4.7          3.2           1.3          0.2     setosa
# 4             4.6          3.1           1.5          0.2     setosa
# 5             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 146           6.7          3.0           5.2          2.3  virginica
# 147           6.3          2.5           5.0          1.9  virginica
# 148           6.5          3.0           5.2          2.0  virginica
# 149           6.2          3.4           5.4          2.3  virginica
# 150           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sb.pairplot( df_iris, hue = 'Species' )
plt.show()
