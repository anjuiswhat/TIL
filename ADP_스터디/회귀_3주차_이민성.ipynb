# %% [markdown]
# ## - 불러올 패키지 목록

# %%
# 파이썬 기본 패키지
import math  # 수학 함수 패키지
import itertools  # Functions creating iterators for efficient looping
from collections import Counter  # label별 데이터 카운트를 위한 모듈

# 데이터 핸들링을 위한 패키지
import numpy as np
import pandas as pd

# missingno 패키지 (데이터 전처리 전 결측치 확인)
import missingno as msno

# 전처리 및 모델 성능평가 관련 패키지
from sklearn.impute import *  # 결측치 처리를 위한 패키지
from sklearn.preprocessing import *  # 데이터 전처리를 위한 패키지
from sklearn.model_selection import *  # 데이터 분리, 검증 및 파라미터 튜닝을 위한 패키지
from sklearn.metrics import *  # 모델에 대한 다양한 성능 평가를 위한 패키지

# 시각화를 위한 패키지
import seaborn as sb
import matplotlib.pyplot as plt
import matplotlib.cm as cm  # 내장 colormap, colormap 처리 유틸리티
from matplotlib.colors import ListedColormap  # colors and colormaps
# %matplotlib inline
# %matplotlib inline 의 목적은 plt.show()함수가 호출되지 않은 경우에도 matplotlib 다이어그램을 렌더링하는 것이다.
# 그러나 현재 업데이트된 버전의 주피터 노트북 버전에서는 %matplotlib inline 를 사용하지 않더라도 Matplotlib 다이어그램을 개체로 표현한다.
# 따라서 굳이 필요하지는 않다. 그러나 코드를 깨끗하게 유지하고 자신이 만든 플롯을 호출하기 위해 여전히 관례적으로 권장된다.

# 경고 메시지 무시
import warnings
warnings.filterwarnings('ignore')

# 그래프 스타일 서식 지정
plt.style.use('default')

# 한글 폰트 설정
plt.rc('font', family='Malgun Gothic')

# 그래프 축의 음수 표현 오류 방지
plt.rcParams['axes.unicode_minus'] = False
#
####################################################################################

# pingouin 패키지 (통계분석 관련)
import pingouin as pg

# SciPy 패키지
import scipy
import scipy.stats as stats  # 통계 분석을 위한 패키지
from scipy.cluster.hierarchy import *  # 계층적 군집 분석을 위한 패키지
from scipy.stats import randint, uniform  # 균일한 이산 확률 변수 및 연속 확률 변수

# statsmodels 패키지
from statsmodels.api import *
from statsmodels.formula.api import *
from statsmodels.stats.api import *
from statsmodels.stats.proportion import *
from statsmodels.stats.diagnostic import *
from statsmodels.stats.weightstats import *
from statsmodels.stats.outliers_influence import *  # 다중공선성 확인 관련 패키지
from statsmodels.multivariate.pca import PCA as stats_PCA  # sklearn 의 PCA와 겹치지 않도록 별칭 지정
from statsmodels.multivariate.pca import pca as stats_pca

# 분산분석 관련 패키지
import scikit_posthocs as sp  # 사후검정
from statsmodels.stats.multicomp import pairwise_tukeyhsd    # 사후검정
from statsmodels.sandbox.stats.multicomp import MultiComparison    # MultiComparison을 활용한 사후검정 시 사용
from statsmodels.graphics.factorplots import interaction_plot    # 상호작용효과 그래프 출력 시 사용

# 요인분석을 위한 패키지
from factor_analyzer import FactorAnalyzer

# 회귀분석 결과 확인을 위한 패키지 (ADP시험 패키지 목록에는 없음)
from regressors import stats as reg

# scikit-learn 패키지
from sklearn.linear_model import *    # 선형 회귀 분석을 위한 패키지 (로지스틱 회귀 포함)

from sklearn.neighbors import *  # kNN 알고리즘 제공
from sklearn.svm import *  # 서포트 벡터 머신 알고리즘 제공
from sklearn.naive_bayes import *  # 나이브베이즈 분류 알고리즘 제공
from sklearn.neural_network import *  # 인공신경망 분류 알고리즘 제공
from sklearn.tree import *  # 결정트리 알고리즘 제공
from sklearn.ensemble import *  # 앙상블 알고리즘 제공
from sklearn.multiclass import OneVsRestClassifier  # multiclass 분류기 알고리즘 제공

from sklearn.cluster import *  # 비지도 군집화 알고리즘 제공
from sklearn.mixture import *  # 혼합분포군집(GMM 등) 알고리즘 제공

from sklearn.decomposition import *  # 차원축소 알고리즘 제공
from sklearn.feature_selection import *  # 알고리즘에 큰 영향을 미치는 feature를 우선순위대로 선택하는 기능 제공
from sklearn.pipeline import *  # feature 처리 등의 변환과 ML 알고리즘 학습/예측 등을 함께 묶어서 실행하는 유틸리티 제공


# mlxtend 패키지
from mlxtend.feature_selection import SequentialFeatureSelector as SFS  # 변수선택 알고리즘 포함
from mlxtend.plotting import plot_sequential_feature_selection as plot_sfs  # 변수선택 시각화
from mlxtend.plotting import plot_decision_regions  # 결정 경계 시각화
from mlxtend.preprocessing import *  # 연관분석에 필요한 트랜잭션 전처리 알고리즘 포함
from mlxtend.frequent_patterns import *  # 연관분석에 사용되는 알고리즘 포함 

# 시계열 관련 statsmodels 패키지
from statsmodels.tsa.api import *
from statsmodels.tsa.ar_model import *
from statsmodels.tsa.arima.model import *
from statsmodels.tsa.arima_process import *
from statsmodels.tsa.statespace import *
from statsmodels.tsa.stattools import *  # 시계열 관련 통계도구
from statsmodels.graphics.api import *
from statsmodels.graphics.tsaplots import *
#
####################################################################################

# %% [markdown]
# ## [ statsmodels 패키지의 API 관련 참고 ]
#
# https://www.statsmodels.org/stable/api.html
#
# 회귀 등의 분석을 위해 `statsmodels.api` 와 `statsmodels.formula.api` 둘 다 사용 가능하지만 용법이 조금씩 다르며, `statsmodels.formula.api`와는 달리 `statsmodels.api`의 경우 회귀분석 수행 전에 상수항을 추가시키는 작업이 필요하다.

# %% [markdown]
# # Data 확인 및 전처리

# %% [markdown]
# ## Dataset 불러오기 및 data 정보 확인

# %%
df = pd.read_csv( r'C:\Users\Boanerges\GitHub\rawdata\kc_house_data.csv')
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
# date 컬럼의 타입을 datetime64 타입으로 변경

df.date = pd.to_datetime( df.date )
df
# Out:
#                id       date     price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520 2014-10-13  221900.0         3       1.00         1180
# 1      6414100192 2014-12-09  538000.0         3       2.25         2570
# 2      5631500400 2015-02-25  180000.0         2       1.00          770
# 3      2487200875 2014-12-09  604000.0         4       3.00         1960
# 4      1954400510 2015-02-18  510000.0         3       2.00         1680
# ...           ...        ...       ...       ...        ...          ...
# 21608   263000018 2014-05-21  360000.0         3       2.50         1530
# 21609  6600060120 2015-02-23  400000.0         4       2.50         2310
# 21610  1523300141 2014-06-23  402101.0         2       0.75         1020
# 21611   291310100 2015-01-16  400000.0         3       2.50         1600
# 21612  1523300157 2014-10-15  325000.0         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  datetime64[ns]
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
# date 컬럼에서 년월까지만 추출하여 저장

df.date = df.date.apply( lambda x : x.year )
df
# Out:
#                id  date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0      7129300520  2014  221900.0         3       1.00         1180      5650
# 1      6414100192  2014  538000.0         3       2.25         2570      7242
# 2      5631500400  2015  180000.0         2       1.00          770     10000
# 3      2487200875  2014  604000.0         4       3.00         1960      5000
# 4      1954400510  2015  510000.0         3       2.00         1680      8080
# ...           ...   ...       ...       ...        ...          ...       ...
# 21608   263000018  2014  360000.0         3       2.50         1530      1131
# 21609  6600060120  2015  400000.0         4       2.50         2310      5813
# 21610  1523300141  2014  402101.0         2       0.75         1020      1350
# 21611   291310100  2015  400000.0         3       2.50         1600      2388
# 21612  1523300157  2014  325000.0         2       0.75         1020      1076
#
# ...

# %%
# 건축시기와 판매시기의 차이를 계산하여 컬럼으로 추가. 나머지 날짜 데이터는 제거

df['sold-build years'] = df.date - df.yr_built
df = df.drop( ['date','yr_built', 'id'], axis=1 )
df
# Out:
#           price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      221900.0         3       1.00         1180      5650     1.0
# 1      538000.0         3       2.25         2570      7242     2.0
# 2      180000.0         2       1.00          770     10000     1.0
# 3      604000.0         4       3.00         1960      5000     1.0
# 4      510000.0         3       2.00         1680      8080     1.0
# ...         ...       ...        ...          ...       ...     ...
# 21608  360000.0         3       2.50         1530      1131     3.0
# 21609  400000.0         4       2.50         2310      5813     2.0
# 21610  402101.0         2       0.75         1020      1350     2.0
# 21611  400000.0         3       2.50         1600      2388     2.0
# 21612  325000.0         2       0.75         1020      1076     2.0
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0               0     0          3      7        1180              0
# ...

# %%
df.yr_renovated = df.yr_renovated.apply( lambda x : 1 if x >0 else 0 )
df
# Out:
#           price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      221900.0         3       1.00         1180      5650     1.0
# 1      538000.0         3       2.25         2570      7242     2.0
# 2      180000.0         2       1.00          770     10000     1.0
# 3      604000.0         4       3.00         1960      5000     1.0
# 4      510000.0         3       2.00         1680      8080     1.0
# ...         ...       ...        ...          ...       ...     ...
# 21608  360000.0         3       2.50         1530      1131     3.0
# 21609  400000.0         4       2.50         2310      5813     2.0
# 21610  402101.0         2       0.75         1020      1350     2.0
# 21611  400000.0         3       2.50         1600      2388     2.0
# 21612  325000.0         2       0.75         1020      1076     2.0
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0               0     0          3      7        1180              0
# ...

# %%
# 상관관계 데이터프레임 생성
df_corr = df.corr()

# 삼각형 마스크를 만든다(위 쪽 삼각형에 True, 아래 삼각형에 False)
mask = np.zeros_like( df_corr, dtype=np.bool )
mask[ np.triu_indices_from( mask ) ] = True

# 히트맵 시각화
plt.figure(figsize=(12,10),
            constrained_layout = True)
sb.heatmap( df_corr,
            annot = True,
            cmap = 'vlag',  # https://seaborn.pydata.org/tutorial/color_palettes.html
            mask = mask,
            vmin = -1, vmax = 1, center = 0)
plt.show()
print()

# %%
# 상관계수 산출 (pingouin 패키지)
df_corr = df.pairwise_corr()

# 상관계수의 절대값 컬럼 추가
df_corr['ABS(r)'] = abs(df_corr['r'])

# 종속변수와의 상관계수의 절대값이 큰 순서대로 정렬
df_corr[ df_corr['X'] == 'price' ].sort_values( 'ABS(r)', ascending = False )
# Out:
#         X                 Y   method alternative      n         r  \
# 2   price       sqft_living  pearson   two-sided  21613  0.702035
# 8   price             grade  pearson   two-sided  21613  0.667434
# 9   price        sqft_above  pearson   two-sided  21613  0.605567
# 15  price     sqft_living15  pearson   two-sided  21613  0.585379
# 1   price         bathrooms  pearson   two-sided  21613  0.525138
# 6   price              view  pearson   two-sided  21613  0.397293
# 10  price     sqft_basement  pearson   two-sided  21613  0.323816
# 0   price          bedrooms  pearson   two-sided  21613  0.308350
# 13  price               lat  pearson   two-sided  21613  0.307003
# 5   price        waterfront  pearson   two-sided  21613  0.266369
# 4   price            floors  pearson   two-sided  21613  0.256794
# 11  price      yr_renovated  pearson   two-sided  21613  0.126092
# 3   price          sqft_lot  pearson   two-sided  21613  0.089661
# ...

# %%
df = df[ ['price', 'sqft_living', 'grade', 'sqft_above', 'sqft_living15', 'bathrooms'] ]
df
# Out:
#           price  sqft_living  grade  sqft_above  sqft_living15  bathrooms
# 0      221900.0         1180      7        1180           1340       1.00
# 1      538000.0         2570      7        2170           1690       2.25
# 2      180000.0          770      6         770           2720       1.00
# 3      604000.0         1960      7        1050           1360       3.00
# 4      510000.0         1680      8        1680           1800       2.00
# ...         ...          ...    ...         ...            ...        ...
# 21608  360000.0         1530      8        1530           1530       2.50
# 21609  400000.0         2310      8        2310           1830       2.50
# 21610  402101.0         1020      7        1020           1020       0.75
# 21611  400000.0         1600      8        1600           1410       2.50
# 21612  325000.0         1020      7        1020           1020       0.75
#
# [21613 rows x 6 columns]

# %%
# 상관관계 데이터프레임 생성
df_corr = df.corr()

# 삼각형 마스크를 만든다(위 쪽 삼각형에 True, 아래 삼각형에 False)
mask = np.zeros_like( df_corr, dtype=np.bool )
mask[ np.triu_indices_from( mask ) ] = True

# 히트맵 시각화
plt.figure(figsize=(12,10),
            constrained_layout = True)
sb.heatmap( df_corr,
            annot = True,
            cmap = 'vlag',  # https://seaborn.pydata.org/tutorial/color_palettes.html
            mask = mask,
            vmin = -1, vmax = 1, center = 0)
plt.show()
print()

# %%
# 상관계수 산출 (pingouin 패키지)
df_corr = df.pairwise_corr()

# 상관계수의 절대값 컬럼 추가
df_corr['ABS(r)'] = abs(df_corr['r'])

# 종속변수와의 상관계수의 절대값이 큰 순서대로 정렬
df_corr[ df_corr['X'] != 'price' ]
# Out:
#                 X              Y   method alternative      n         r  \
# 5     sqft_living          grade  pearson   two-sided  21613  0.762704
# 6     sqft_living     sqft_above  pearson   two-sided  21613  0.876597
# 7     sqft_living  sqft_living15  pearson   two-sided  21613  0.756420
# 8     sqft_living      bathrooms  pearson   two-sided  21613  0.754665
# 9           grade     sqft_above  pearson   two-sided  21613  0.755923
# 10          grade  sqft_living15  pearson   two-sided  21613  0.713202
# 11          grade      bathrooms  pearson   two-sided  21613  0.664983
# 12     sqft_above  sqft_living15  pearson   two-sided  21613  0.731870
# 13     sqft_above      bathrooms  pearson   two-sided  21613  0.685342
# 14  sqft_living15      bathrooms  pearson   two-sided  21613  0.568634
#
#            CI95%  p-unc BF10  power    ABS(r)
# 5   [0.76, 0.77]    0.0  inf    1.0  0.762704
# 6   [0.87, 0.88]    0.0  inf    1.0  0.876597
# 7   [0.75, 0.76]    0.0  inf    1.0  0.756420
# ...

# %%
df = df[['price', 'sqft_living']]

# %%
# boxplot을 사용한 이상치 확인

plt.figure( figsize=(15,10),
            constrained_layout = True )

for i in range(0, df.columns.size):
    plt.subplot( 8, 4, i+1 ) # 그래프 배열 4행 8열
    sb.boxplot( df.iloc[:, i] )

# %%
# 데이터 분포 확인

plt.figure( figsize=(12, 18),
            constrained_layout = True)

for i in range(0, df.columns.size ):
    plt.subplot( 8, 4, i+1 ) # 그래프 배열 n행 m열
    sb.histplot( df.iloc[:, i], kde = True )

# %% [markdown]
# # =================================

# %% [markdown]
# # 로그변환

# %%
df = np.log1p( df )
df
# Out:
#            price  sqft_living
# 0      12.309987     7.074117
# 1      13.195616     7.852050
# 2      12.100718     6.647688
# 3      13.311331     7.581210
# 4      13.142168     7.427144
# ...          ...          ...
# 21608  12.793862     7.333676
# 21609  12.899222     7.745436
# 21610  12.904461     6.928538
# 21611  12.899222     7.378384
# 21612  12.691584     6.928538
#
# [21613 rows x 2 columns]

# %%
# boxplot을 사용한 이상치 확인

plt.figure( figsize=(15,10),
            constrained_layout = True )

for i in range(0, df.columns.size):
    plt.subplot( 8, 4, i+1 ) # 그래프 배열 4행 8열
    sb.boxplot( df.iloc[:, i] )

# %%
# 데이터 분포 확인 

plt.figure( figsize=(12, 18),
            constrained_layout = True)

for i in range(0, df.columns.size ):
    plt.subplot( 8, 4, i+1 ) # 그래프 배열 n행 m열
    sb.histplot( df.iloc[:, i], kde = True )

# %% [markdown]
# # 스케일링

# %%
scaler = StandardScaler()

df = pd.DataFrame( scaler.fit_transform( df ),
                   columns = df.columns)
df
# Out:
#           price  sqft_living
# 0     -1.400936    -1.123053
# 1      0.280624     0.709313
# 2     -1.798279    -2.127474
# 3      0.500335     0.071368
# 4      0.179141    -0.291522
# ...         ...          ...
# 21608 -0.482193    -0.511679
# 21609 -0.282144     0.458190
# 21610 -0.272197    -1.465953
# 21611 -0.282144    -0.406374
# 21612 -0.676391    -1.465953
#
# [21613 rows x 2 columns]

# %%
# boxplot을 사용한 이상치 확인

plt.figure( figsize=(15,10),
            constrained_layout = True )

for i in range(0, df.columns.size):
    plt.subplot( 8, 4, i+1 ) # 그래프 배열 4행 8열
    sb.boxplot( df.iloc[:, i] )

# %%
# 데이터 분포 확인

plt.figure( figsize=(12, 18),
            constrained_layout = True)

for i in range(0, df.columns.size ):
    plt.subplot( 8, 4, i+1 ) # 그래프 배열 n행 m열
    sb.histplot( df.iloc[:, i], kde = True )

# %% [markdown]
# # 이상치 제거

# %%
# 이상치를 제거한 데이터프레임을 생성하는 함수 

def get_outlier_drop( df=None, outlier_columns=None, weight=1.5):

    outlier_index = list()
    df_outlier_drop = df.copy()
    
    
    for i in range(0, outlier_columns.shape[1]):  # 분류분석의 경우 'Class' 변수를 제외하고 이상치를 탐색하기 위해 범위를 조정할 필요가 있다.
                                     # 종속변수 'Class'의 경우, 분포 불균형으로 인해 1을 모두 이상치로 인식함.  
        
        # col에 해당하는 column 데이터만 추출, 1/4 분위와 3/4 분위 지점을 np.percentile로 구함. 
        col = outlier_columns.iloc[:,i]
        quantile_25 = col.quantile(0.25)
        quantile_75 = col.quantile(0.75)
        
        # IQR을 구하고, IQR에 1.5를 곱하여 최대값과 최소값 지점 구함. 
        iqr = quantile_75 - quantile_25
        iqr_weight = iqr * weight
        lowest_val = quantile_25 - iqr_weight
        highest_val = quantile_75 + iqr_weight
        
        # 최대값 보다 크거나, 최소값 보다 작은 값을 이상치로 설정하고 이상치와 해당 index를 반환.
        outlier = col[ (col < lowest_val) | (col > highest_val) ]
        
        # 이상치가 존재하는 행 index 주소를 리스트에 추가
        if len(outlier) == 0:
            pass
        else:
            outlier_index.extend( outlier.index )
            
    # 이상치가 존재하는 행을 모두 제거한 데이터프레임 생성
    df_outlier_drop = df_outlier_drop.drop( np.unique(outlier_index), axis=0 )
        
    return df_outlier_drop

# %%
df = get_outlier_drop( df = df,
                       outlier_columns = df )
df
# Out:
#           price  sqft_living
# 0     -1.400936    -1.123053
# 1      0.280624     0.709313
# 2     -1.798279    -2.127474
# 3      0.500335     0.071368
# 4      0.179141    -0.291522
# ...         ...          ...
# 21608 -0.482193    -0.511679
# 21609 -0.282144     0.458190
# 21610 -0.272197    -1.465953
# 21611 -0.282144    -0.406374
# 21612 -0.676391    -1.465953
#
# [21219 rows x 2 columns]

# %%
# boxplot을 사용한 이상치 확인

plt.figure( figsize=(15,10),
            constrained_layout = True )

for i in range(0, df.columns.size):
    plt.subplot( 8, 4, i+1 ) # 그래프 배열 4행 8열
    sb.boxplot( df.iloc[:, i] )

# %%
# 데이터 분포 확인 (distplot())

plt.figure( figsize=(12, 18),
            constrained_layout = True)

for i in range(0, df.columns.size ):
    plt.subplot( 8, 4, i+1 ) # 그래프 배열 n행 m열
    sb.histplot( df.iloc[:, i], kde = True )

# %%
df = get_outlier_drop( df = df,
                       outlier_columns = df )
df
# Out:
#           price  sqft_living
# 0     -1.400936    -1.123053
# 1      0.280624     0.709313
# 2     -1.798279    -2.127474
# 3      0.500335     0.071368
# 4      0.179141    -0.291522
# ...         ...          ...
# 21608 -0.482193    -0.511679
# 21609 -0.282144     0.458190
# 21610 -0.272197    -1.465953
# 21611 -0.282144    -0.406374
# 21612 -0.676391    -1.465953
#
# [21166 rows x 2 columns]

# %%
df = get_outlier_drop( df = df,
                       outlier_columns = df )
df
# Out:
#           price  sqft_living
# 0     -1.400936    -1.123053
# 1      0.280624     0.709313
# 2     -1.798279    -2.127474
# 3      0.500335     0.071368
# 4      0.179141    -0.291522
# ...         ...          ...
# 21608 -0.482193    -0.511679
# 21609 -0.282144     0.458190
# 21610 -0.272197    -1.465953
# 21611 -0.282144    -0.406374
# 21612 -0.676391    -1.465953
#
# [21150 rows x 2 columns]

# %%
df = get_outlier_drop( df = df,
                       outlier_columns = df )
df
# Out:
#           price  sqft_living
# 0     -1.400936    -1.123053
# 1      0.280624     0.709313
# 2     -1.798279    -2.127474
# 3      0.500335     0.071368
# 4      0.179141    -0.291522
# ...         ...          ...
# 21608 -0.482193    -0.511679
# 21609 -0.282144     0.458190
# 21610 -0.272197    -1.465953
# 21611 -0.282144    -0.406374
# 21612 -0.676391    -1.465953
#
# [21145 rows x 2 columns]

# %%
# boxplot을 사용한 이상치 확인

plt.figure( figsize=(15,10),
            constrained_layout = True )

for i in range(0, df.columns.size):
    plt.subplot( 8, 4, i+1 ) # 그래프 배열 4행 8열
    sb.boxplot( df.iloc[:, i] )

# %%
# 데이터 분포 확인 (distplot())

plt.figure( figsize=(12, 18),
            constrained_layout = True)

for i in range(0, df.columns.size ):
    plt.subplot( 8, 4, i+1 ) # 그래프 배열 n행 m열
    sb.histplot( df.iloc[:, i], kde = True )

# %%
# 데이터 분포 확인 (distplot())

plt.figure( figsize=(12, 18),
            constrained_layout = True)

for i in range(0, df.columns.size ):
    plt.subplot( 8, 4, i+1 ) # 그래프 배열 n행 m열
    sb.distplot( df.iloc[:, i], kde = True, fit = stats.norm )

# %%
# Kolmogorov-Smirnov test (n >= 5000 일 경우)

for i in range(0, df.columns.size):
    print( df.iloc[:,i].name, '의 정규성 검정 p값 =', kstest_normal( df.iloc[:,i], dist = 'norm', pvalmethod = 'table' )[1] )
# Out:
# price 의 정규성 검정 p값 = 0.0009999999999998899
# sqft_living 의 정규성 검정 p값 = 0.0009999999999998899

# %%
# 정규성 확인 (잔차플롯)

plt.figure( figsize=(12, 20),
            constrained_layout = True)

for i in range(0, df.columns.size):
    plt.subplot( 8, 4, 1+i ) # 그래프 배열 4행 8열
    plt.settitle = df.iloc[:, i].name
    stats.probplot( df.iloc[:, i], plot = plt )

# %% [markdown]
# # =================================

# %% [markdown]
# # 변수 지정 및 훈련/테스트 데이터 분리

# %% [markdown]
# ## x값(예측변수), y값(목표변수) 설정

# %%
# 목표변수, 종속변수 지정
y = df.iloc[:, 0]
x = df.iloc[:, 1:]

# %% [markdown]
# ## 학습/테스트용 데이터셋 분리
# - `sklearn.model_selection.train_test_split( *arrays, test_size=None, train_size=None, random_state=None, shuffle=True, stratify=None )`
# https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html

# %%
# 데이터셋 나누고 라벨 분포 확인
x_train, x_test, y_train, y_test  = train_test_split( x, y,
                                                      test_size = 0.3,
                                                      random_state = 0 )

# %% [markdown]
# # 회귀분석 수행
#
# - y = α + β1·x1 + β2·x2 + ... + βp·xp + ε
#
#
# - 귀무가설 H0 : β1 = β2 = ... = βp = 0
# - 대립가설 H1 : β1 ~ βp 중 적어도 하나 이상의 계수는 0 이 아니다.

# %% [markdown]
# ## [ 참고 ] `statsmodels`을 사용한 회귀분석 시 유의사항
#
# - statsmodels 패키지는 sklearn 과는 달리 회귀분석 결과와 관련된 수치들을 손쉽게 출력할 수 있는 방법을 제공하지만 해당 방법들의 대다수가 회귀모델 적합 시 생성된 값들, 즉, training data로 학습/예측한 결과만 확인할 수 있다는 단점이 있다.
#
# - 예를 들어 적합된 모델로 training data에 대한 '예측값', '잔차', 'MSE', 'R-squared', 'Adj. R-squared' 등을 바로 출력하는 메서드나 속성을 지원하지만, test data에 대한 해당 통계량에 대해서는 지원하지 않는다.
#
# - 즉, statsmodels의 많은 메서드/속성들이 'training data'를 사용하여 적합된 회귀모델에 'test data'를 적용하여 예측한 결과에 대한 출력은 지원하지 않으며, 이 경우에는 결국 sklearn 패키지로 만든 회귀분석 결과를 검토했을 때와 마찬가지로 별도의 코드를 작성하여 적용해야 한다.

# %% [markdown]
# ## 모델 생성 및 적합
#
# - 회귀모델 생성 방법(1)
#   - `statsmodels.regression.linear_model.OLS( endog, exog=None, missing='none', hasconst=None, **kwargs )`
#     - https://www.statsmodels.org/stable/generated/statsmodels.regression.linear_model.OLS.html
#     - [ 주의!!! ] 상수항 추가 작업 필요
#
#
# - 회귀모델 생성 방법(2)
#   - `statsmodels.formula.api.ols( formula, data, subset=None, drop_cols=None, *args, **kwargs )`
#     - https://www.statsmodels.org/stable/generated/statsmodels.formula.api.ols.html
#     - 상수항 추가 작업 불필요
#       - [ 예시 ] :  model = ols( formula = 'MEDV ~ CRIM + ZN + INDUS + CHAS + NOX + RM + AGE + DIS + RAD + TAX + PTRATIO + B + LSTAT', data = df )
#
#
#
# - 모델 적합
#   - `OLS.fit(method='pinv', cov_type='nonrobust', cov_kwds=None, use_t=None, **kwargs)`
#     - https://www.statsmodels.org/stable/generated/statsmodels.regression.linear_model.OLS.fit.html
#     - Returns : `RegressionResults`
#       - https://www.statsmodels.org/stable/generated/statsmodels.regression.linear_model.RegressionResults.html
#       - Attributes:
#         - 예측값(Training Data) : `.fittedvalues`
#         - 잔차 : `.resid`
#         - 단위 분산을 갖도록 정규화된 잔차 : `.resid_pearson`
#         - 잔차의 MSE (Mean Squared Error) : `.mse_resid`
#         - R-squared : `.rsquared`
#         - Adj. R-squared : `.rsquared_adj`
#         - 회귀모델의 F-통계량 및 p-value : `.fvalue`, `.f_pvalue`
#         - 회귀계수 : `.params`
#         - 회귀계수의 Standard Error : `.bse`
#         - 회귀계수의 t-통계량 및 p-value : `.tvalues`, `.pvalues`
#         - Condition Number (상태지수; 조건수) : `.condition_number`
#       - Methods:
#         - `.predict( exog=None, transform=True, *args, **kwargs )` : 적합된 모델을 사용하여 반응변수 예측
#           - https://www.statsmodels.org/stable/generated/statsmodels.regression.linear_model.RegressionResults.predict.html
#         - `.summary( yname=None, xname=None, title=None, alpha=0.05 )` : 회귀 결과 요약
#           - https://www.statsmodels.org/stable/generated/statsmodels.regression.linear_model.RegressionResults.summary.html
#         - `.get_prediction( exog=None, transform=True, weights=None, row_labels=None, **kwargs )`
#           - https://www.statsmodels.org/stable/generated/statsmodels.regression.linear_model.RegressionResults.get_prediction.html
#           - Returns : `PredictionResults`
#             - 데이터프레임으로 반환해야 결과를 볼 수 있음.
#             - Methods : `.summary_frame( alpha=0.05 )`

# %%
# `statsmodels.api.OLS()` 사용 시, fomula 형식의 파라미터 입력 불가. X, Y 를 따로 설정하여 입력
# 상수항을 따로 추가시켜주는 작업 필요.

# x_train에 상수항 추가
x_train_c = add_constant( x_train )

# 모델 생성
model = OLS( y_train, x_train_c )

# 모델 적합
fit_model = model.fit()

# %% [markdown]
# ## 회귀 결과 요약 report 확인
#
# - `RegressionResults.summary( yname=None, xname=None, title=None, alpha=0.05 )`
#   - https://www.statsmodels.org/stable/generated/statsmodels.regression.linear_model.RegressionResults.summary.html
#
#
# - summary 에서 확인할 수 있는 사항
#   - 회귀계수 및 상수항
#   - 평가 지표:
#     - 모형의 설명력: 결정계수(R-squared), 수정된 결정계수(Adj. R-squared)
#   - 회귀분석 결과 검정:
#     - 모형의 통계적 유의성: F-통계량 및 p-value (F-검정)
#     - 회귀계수의 유의성: t-통계량 및 p-value (t-검정)
#   - 잔차분석 관련
#     - 오차항의 독립성: Durbin-Watson 통계량
#   - 다중공선성 관련: Condition Number (상태지수 또는 조건수)

# %%
print( fit_model.summary(alpha = 0.05) )
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.405
# Model:                            OLS   Adj. R-squared:                  0.405
# Method:                 Least Squares   F-statistic:                 1.009e+04
# Date:                Fri, 12 Nov 2021   Prob (F-statistic):               0.00
# Time:                        05:28:33   Log-Likelihood:                -15864.
# No. Observations:               14801   AIC:                         3.173e+04
# Df Residuals:                   14799   BIC:                         3.175e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const          -0.0290      0.006     -4.992      0.000      -0.040      -0.018
# ...

# %% [markdown]
# ## 예측 및 잔차/평가지표 확인

# %% [markdown]
# ### 반응변수에 대한 예측

# %%
# x_test에 상수항 추가 (x_train 은 모델 생성할 때 이미 추가한 상태)
x_test_c = add_constant( x_test )

# 예측
pred_train = fit_model.fittedvalues  # 또는 fit_model.predict( x_train_c )
pred_test = fit_model.predict( x_test_c )

# 잔차 계산
resid_train = fit_model.resid  # ( y_train - pred_train )도 가능
resid_test = y_test - pred_test

# 데이터프레임으로 출력
result_train = pd.DataFrame( {'y_Test' : y_train,
                              'Predict_Test' : pred_train,
                              'resid' : resid_train} )

result_test = pd.DataFrame( {'y_Test' : y_test,
                              'Predict_Test' : pred_test,
                              'resid' : resid_test} )

print('< 훈련 데이터로 예측한 결과 >')
display( result_train )
print()
print('< 테스트 데이터로 예측한 결과 >')
display( result_test )
# Out:
# < 훈련 데이터로 예측한 결과 >
#          y_Test  Predict_Test     resid
# 4329  -1.357792     -1.175659 -0.182133
# 3488  -0.676684     -0.410881 -0.265802
# 8377  -0.260903     -1.280131  1.019228
# 7614  -0.189731     -0.132579 -0.057152
# 1103  -1.646301     -0.623800 -1.022501
# ...         ...           ...       ...
# 13383 -1.357792     -0.362213 -0.995579
# 20069  1.863002      1.270085  0.592917
# 10040  0.433145      0.806909 -0.373765
# 11009 -0.535682      0.252333 -0.788015
# 2784  -0.590721      0.864192 -1.454913
#
# [14801 rows x 3 columns]
# < 테스트 데이터로 예측한 결과 >
#          y_Test  Predict_Test     resid
# 17544 -0.212245     -0.333778  0.121534
# 8894  -1.560631     -0.694308 -0.866323
# 15453  0.406910     -0.986949  1.393859
# 18926  0.610259      0.649352 -0.039093
# 739   -1.308257     -0.471532 -0.836725
# ...         ...           ...       ...
# 12514 -0.503408     -1.078228  0.574820
# 3824   0.875627      0.029489  0.846138
# 15118  2.350035      0.968179  1.381855
# ...

# %% [markdown]
# ### 예측값의 신뢰구간

# %%
pred_train_interval = fit_model.get_prediction( x_train_c )
pred_test_interval = fit_model.get_prediction( x_test_c )

print('< 훈련 데이터로 예측한 값의 신뢰구간 >')
display( pred_train_interval.summary_frame() )
print()

print('< 테스트 데이터로 예측한 값의 신뢰구간 >')
display( pred_test_interval.summary_frame() )
print()
# Out:
# < 훈련 데이터로 예측한 값의 신뢰구간 >
#            mean   mean_se  mean_ci_lower  mean_ci_upper  obs_ci_lower  \
# 4329  -1.175659  0.012673      -1.200500      -1.150818     -2.561232
# 3488  -0.410881  0.006860      -0.424327      -0.397435     -1.796297
# 8377  -1.280131  0.013606      -1.306800      -1.253461     -2.665738
# 7614  -0.132579  0.005875      -0.144095      -0.121063     -1.517978
# 1103  -0.623800  0.008187      -0.639847      -0.607753     -2.009244
# ...         ...       ...            ...            ...           ...
# 13383 -0.362213  0.006615      -0.375178      -0.349247     -1.747624
# 20069  1.270085  0.014322       1.242012       1.298157     -0.115550
# 10040  0.806909  0.010278       0.786763       0.827055     -0.578588
# 11009  0.252333  0.006518       0.239557       0.265110     -1.133076
# 2784   0.864192  0.010753       0.843114       0.885270     -0.521319
#
#        obs_ci_upper
# 4329       0.209914
# 3488       0.974534
# 8377       0.105477
# ...

# %% [markdown]
# ### 평가 지표
#
# - MSE (Mean Squared Error) : 실제값과 예측값의 차이를 제곱하여 평균 (오류의 제곱을 구하므로 실제 오류 평균보다 더 커지는 특성이 있음)
#
#
# - RMSE (Root Mean Squared Error) : MSE에 루트를 씌운 값
#   - `sklearn.metrics.mean_squared_error( y_true, y_pred, *, sample_weight=None, multioutput='uniform_average', squared=True )`
#     - https://scikit-learn.org/stable/modules/generated/sklearn.metrics.mean_squared_error.html
#     - MSE : squared = True (기본값)
#     - RMSE : squared = False
#
#
# - MAE (Mean Absolute Error) : 실제값과 예측값의 차이를 절대값으로 변환하여 평균
#   - `sklearn.metrics.mean_absolute_error( y_true, y_pred, *, sample_weight=None, multioutput='uniform_average' )`
#     - https://scikit-learn.org/stable/modules/generated/sklearn.metrics.mean_absolute_error.html

# %%
# R-squared
r2_train = fit_model.rsquared  # r2_score( y_train, pred_train ) 또는 model.score( x_train, y_train )도 가능
r2_test = r2_score( y_test, pred_test )  # 또는 model.score( x_test, y_test )

# MSE (Mean Squared Error)
mse_train = fit_model.mse_resid  # mean_squared_error( y_train, pred_train )도 가능. 약간의 수치 차이는 있음.
mse_test = mean_squared_error( y_test, pred_test )

# RMSE (Root Mean Squared Error)
rmse_train = np.sqrt( fit_model.mse_resid )  # mean_squared_error( y_train, pred_train, squared=False )도 가능. 약간의 수치 차이는 있음.
rmse_test = mean_squared_error( y_test, pred_test, squared=False )

# MAE (Mean Absolute Error)
mae_train = mean_absolute_error( y_train, pred_train )
mae_test = mean_absolute_error( y_test, pred_test )

print( '< 평가지표 (Training Data) >')
print( 'R-squared: %.4f' % r2_train )
print( 'RMSE: %.4f' % rmse_train )
print( 'MSE: %.4f' % mse_train )
print( 'MAE: %.4f' % mae_train )
print()
print( '< 평가지표 (Test Data) >')
print( 'R-squared: %.4f' % r2_test )
print( 'RMSE: %.4f' % rmse_test )
print( 'MSE: %.4f' % mse_test )
print( 'MAE: %.4f' % mae_test )
print()
# Out:
# < 평가지표 (Training Data) >
# R-squared: 0.4053
# RMSE: 0.7068
# MSE: 0.4995
# MAE: 0.5805
#
# < 평가지표 (Test Data) >
# R-squared: 0.4137
# RMSE: 0.6964
# MSE: 0.4849
# MAE: 0.5710

# %% [markdown]
# # =================================

# %% [markdown]
# # 회귀분석 모델 검토

# %% [markdown]
# ## 모형의 적합성
#
# - 모형이 데이터를 잘 적합하고 있는지 잔차와 종속변수의 산점도로 확인

# %%
# 데이터 분포 확인 (distplot())

plt.figure( figsize=(12, 18),
            constrained_layout = True)

for i in range(0, x_train.columns.size ):
    plt.subplot( 8, 4, i+1 ) # 그래프 배열 n행 m열
    plt.title( x_train.iloc[:,i].name )
    sb.regplot( x_train.iloc[:,i].values,
                y_train.values )

# %% [markdown]
# ## 모형의 설명력 ( $R^2$ 또는 Adjusted $R^2$ )
#
# - '결정계수' 또는 '수정된 결정계수' 확인

# %%
n = y_train.size  # train 데이터의 Target 값 개수
k = x_train.shape[1]  # 목표 변수의 개수

# R-squared
r2 = fit_model.rsquared    # r2_score( y_train, pred_train ) 또는 model.score( x_train, y_train )도 가능

# Adj. R-squared
r2_adj = fit_model.rsquared_adj

print( 'R-squared: %.4f' % r2 )
print( 'Adj. R-squared: %.4f' % r2_adj )
print()
# Out:
# R-squared: 0.4053
# Adj. R-squared: 0.4052

# %% [markdown]
# ## 모형의 통계적 유의성 (F-검정)
#
# - F-통계량으로 확인

# %%
# F-statistic
f_stat = fit_model.fvalue
p_val_f = fit_model.f_pvalue

print('F-statistic: %.4f' % f_stat )
print('p-value(of F-stat.): %.4f' % p_val_f )
print()
# Out:
# F-statistic: 10085.1384
# p-value(of F-stat.): 0.0000

# %% [markdown]
# ## 회귀계수의 유의성 (t-검정)
#
# - 계수들의 t-통계량을 통해 확인

# %%
stat_result = pd.DataFrame()
stat_result['Feature'] = x_train_c.columns

stat_result['Coefficients'] = fit_model.params.values
stat_result['Standard Errors'] = fit_model.bse.values
stat_result['t-statistic'] = fit_model.tvalues.values
stat_result['p-value'] = fit_model.pvalues.values

stat_result.round(4)
# Out:
#        Feature  Coefficients  Standard Errors  t-statistic  p-value
# 0        const        -0.029           0.0058      -4.9917      0.0
# 1  sqft_living         0.614           0.0061     100.4248      0.0

# %% [markdown]
# ## 다중공선성 진단

# %% [markdown]
# ### VIF (분산팽창요인; 분산확대인자)
#
# - 4보다 크면 다중공선성이 존재한다고 볼 수 있고
# - 10보다 크면(즉, 해당 변수의 변이가 다른 설명변수들에 의해서 90% 이상 설명이 되면) 다중공선성이 심각한 것으로 간주한다.
#
#
# - `statsmodels.stats.outliers_influence.variance_inflation_factor( exog, exog_idx )`
#   - https://www.statsmodels.org/stable/generated/statsmodels.stats.outliers_influence.variance_inflation_factor.html
#   - Parameters :
#     - `exog` : 설명변수의 데이터 배열
#     - `exog_idx` : exog의 컬럼의 인덱스

# %%
# 분산확대인자를 데이터프레임 형식으로 출력 (1)

VIF = pd.DataFrame()
VIF['features'] = x_train_c.columns
VIF['VIF factor'] = [ variance_inflation_factor(x_train_c.values, i) for i in range(x_train_c.shape[1]) ]

VIF.round(3)
# Out:
#       features  VIF factor
# 0        const       1.001
# 1  sqft_living       1.000

# %% [markdown]
# ### Condition Number (상태지수; 조건수)
#
# - 조건수(condition number)는 argument에서의 작은 변화의 비율에 대해 함수가 얼마나 변화할 수 있는지 에 대한 argument measure이다.
# - 조건수가 크면 약간의 오차만 있어도 해가 전혀 다른 값을 가진다. 따라서 조건수가 크면 회귀분석을 사용한 예측값도 오차가 커지게 된다.
#
#
# - 회귀분석에서 Condition Number가 커지는 원인은 크게 두 가지가 있다.
#   - 변수들의 단위 차이로 인해 숫자의 스케일이 크게 달라지는 경우. 이 경우에는 스케일링(scaling)으로 해결한다.
#   - 다중 공선성 즉, 상관관계가 큰 독립 변수들이 있는 경우. 이 경우에는 변수 선택이나 PCA를 사용한 차원 축소 등으로 해결한다.
#
#
# - 다중공선성 측면만 본다면 (스케일링 측면의 문제가 없다고 가정하면)
#   - 상태지수가 10보다 크면 다중공선성이 어느 정도 존재 하는 것으로 간주.
#   - 상태지수가 30보다 크면 다중공선성이 매우 심각한 것으로 간주.
#
#
# - [ 참고 ] `statsmodels` 패키지로 생성/적합된 모델에서의 확인 방법
#   - `RegressionResults.condition_number`
#   - `RegressionResults.summary()`의 `Cond. No.` 항목에서도 확인 가능.
#
# ==========================================================================================

# %%
# 상태지수 확인
print( 'condition number =', fit_model.condition_number.round(3) )
print()
# Out:
# condition number = 1.059

# %% [markdown]
# ### 다중공선성에 대한 대책
#
# - 다중공선성과 관련있는 일부 변수 제거 ( 예: 변수선택법 등)
#
# - 더 넓은 범위의 독립변수들의 값에서 새로운 관측치를 얻어낸다.
#
# - 능형회귀(예: Ridge, Lasso, Elastic Net 등) 또는 주성분 분석 등의 편의 추정법을 사용한다.
#
#
# ==========================================================================================

# %% [markdown]
# ## 잔차 분석

# %% [markdown]
# ### 오차의 독립성 (Durbin-Watson 통계량)
#
# - 오차들은 서로 독립적이라는 가정.
# - 즉, 예측값의 변화에 따라 오차항이 특정한 패턴을 가져서는 안된다.
#
# - Durbin-Watson 통계량을 확인한다.
#   - 2 에 가까우면 오차항의 독립성 만족,
#   - 0 에 가까우면 양(+)의 자기상관관계,
#   - 4 에 가까우면 음(-)의 자기상관관계
#   - 자기상관성은 흔히 시간에 따라 관측된 시계열 데이터에서 많이 발생하는데, 자기상관성이 있는 것으로 판단되면, ARMA(자기회귀 이동평균)와 같은 시계열데이터 분석방법을 이용하는 것이 바람직하다.
#
#
# - `statsmodels.stats.stattools.durbin_watson( resids, axis=0 )`
#   - https://www.statsmodels.org/stable/generated/statsmodels.stats.stattools.durbin_watson.html
#   - `statsmodels` 패키지로 생성/적합된 모델의 경우, 회귀 결과 요약 `RegressionResults.summary()`의 Durbin-Watson 항목에서도 확인 가능하다.

# %%
# 더빈-왓슨 통계량
print( 'Durbin-Watson 통계량:', durbin_watson( resid_train ) )
print()
# Out:
# Durbin-Watson 통계량: 1.9746536401302759

# %% [markdown]
# ### 오차의 등분산성
#
# - 오차의 분산은 독립변수의 값과 무관하게 일정해야 한다.

# %%
# 잔차의 등분산 확인

sb.residplot( x = pred_train, y = resid_train )
plt.show()

# %% [markdown]
# ### 오차의 정규성
#
# - 오차의 분포가 정규분포를 만족해야 한다.

# %% [markdown]
# #### 시각화를 통한 대략적인 분포 확인

# %%
sb.distplot( resid_train )
plt.show()

# %% [markdown]
# #### Shapiro-Wilk test (n < 5000 일 경우)
#
# - 자료 값들과 표준정규점수와의 선형상관 관계를 측정하여 검정하는 방법
#
#
# - `scipy.stats.shapiro( x )`
#   - Returns : `.statistic`, `.pvalue`
#   - https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.shapiro.html

# %%
result = stats.shapiro( resid_train )

print( f'Statistics: {result[0]:.4f} \nP-value: {result[1]:.12f}' )
print()
# Out:
# Statistics: 0.9951
# P-value: 0.000000000000

# %% [markdown]
# #### Kolmogorov-Smirnov test  (n ≥ 5000 일 경우)
#
# - 자료의 가장 작은 값부터 가장 큰 값까지의 누적상대빈도가 이론적 정규분포에서의 누적상대빈도와 얼마나 다른가를 측정하여 검정하는 방법
#
#
# - `statsmodels.stats.diagnostic.kstest_normal( x, dist='norm', pvalmethod='table' )`
#   - dist : 가정된 분포
#   - pvalmethod : 검정 통계량의 p-값을 계산하는데 사용되는 방법
#   - Returns : `ksstat`, `pvalue`
#   - https://www.statsmodels.org/stable/generated/statsmodels.stats.diagnostic.kstest_normal.html

# %%
result = kstest_normal( resid_train )

print( f'Statistics: {result[0]:.4f} \nP-value: {result[1]:.12f}' )
print()
# Out:
# Statistics: 0.0334
# P-value: 0.001000000000

# %% [markdown]
# #### Q-Q plot (정규확률도표): `probplot()` - SciPy
#
# - `scipy.stats.probplot( x, sparams=(), dist='norm', fit=True, plot=None, rvalue=False )`
#   - https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.probplot.html

# %%
# Q-Q plot
stats.probplot( resid_train, plot = plt )
plt.show()
print()

# %% [markdown]
# ## 회귀진단 결과 플로팅
#
# - [주의!!] 아래의 명령어는 모두 'Training Data'에 대한 회귀결과를 출력한다.
#
# - `statsmodels.graphics.regressionplots.plot_regress_exog(results, exog_idx, fig=None)`
#   - https://www.statsmodels.org/stable/generated/statsmodels.graphics.regressionplots.plot_regress_exog.html
#
#
# - 아래 4가지 사항에 대한 그래프를 동시에 출력한다.
#
#
# 1. 실제값과 적합값 그래프
#
#
# 2. 잔차 그래프
#
#
# 3. 부분회귀 플롯(Partial Regression Plot)
#   - 독립변수의 갯수가 많을 때, 특정한 하나의 독립변수의 영향력을 시각화하는 방법
#   - Added Variable Plot이라고도 한다.
#   - 부분회귀 플롯을 그리기 위해서는 3번의 선형 회귀분석을 해야 한다.
#     - 1) 특정한 독립변수 x2를 제외한 나머지 독립변수 X1들로 종속변수 y를 선형 회귀분석하여 잔차 y'를 구한다.
#     - 2) 특정한 독립변수 x2를 제외한 나머지 독립변수 X1들로 특정한 독립변수 x2를 선형 회귀분석하여 잔차 x2'를 구한다.
#     - 3) 잔차 x2'를 독립변수로, 잔차 y'를 종속변수로 하여 선형 회귀분석한다.
#     - 이렇게 구한 x2', y'의 스캐터 플롯과 회귀분석 결과를 나타낸 것이 부분회귀 플롯이다.
#
#
# 4. CCPR(Component-Component plus Residual)
#   - 부분회귀 플롯과 마찬가지로 특정한 하나의 변수의 영향을 살펴보기 위한 것이다.
#   - 다음과 같은 회귀 모형이 있다고 가정하자.
#     - y = y' + e = w1x1 + w2x2 + ⋯ + wixi + ⋯ + wKxK + e
#   - CCPR 플롯은 이 성분 중에서 xi 를 가로축으로 (wixi + e)를 세로축으로 그린 스캐터 플롯이다.

# %%
fig = plt.figure(figsize = (8, 6))

plot_regress_exog( fit_model,
                   df.iloc[:,1].name,
                   fig = fig)
plt.show()
# Out:
# eval_env: 1

# %% [markdown]
# # =================================

# %%
asdf
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\BOANER~1\AppData\Local\Temp/ipykernel_17712/2827374946.py in <module>
# ----> 1 asdf
#
# NameError: name 'asdf' is not defined

# %% [markdown]
# ## [ 미해결 ] F-test로 다중공선성 확인?? 무슨 관련이 있는가??

# %%
df_multico = pd.read_csv(r'C:\Users\Boanerges\GitHub\rawdata\Multico.csv',
                         index_col = 'ID')

df_multico

# %%
model_mtc = ols( data = df_multico, formula = 'Y ~ X1+X2+X3+X4')

fit_mtc = model_mtc.fit()

print( fit_mtc.summary() )
print()

# %%
# 분산분석 F-test
anova_lm( fit_mtc, test = 'F', typ = 1).round(4)
